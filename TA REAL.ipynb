# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# Load the .wav file
sample_rate, data = wavfile.read('C:/Users/Axioo Pongo/Documents/BYB/SpikerBox dengan input 50 mV.wav')

# Print basic info
print(f"Sample rate: {sample_rate} Hz")
print(f"Data shape: {data.shape}")

# If stereo, take only one channel
if len(data.shape) > 1:
    data = data[:, 0]  # use left channel

# Find max peak amplitude
peak_amplitude = np.max(np.abs(data))
print(f"Maximum peak amplitude: {peak_amplitude}")

# Create time axis in seconds
time = np.linspace(0, len(data) / sample_rate, num=len(data))

# Plot the waveform
plt.figure(figsize=(12, 4))
plt.plot(time, data)
plt.title("SpikerBox dengan input 50 mV sine wave 70 Hz")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Sample rate: 5000 Hz
# Data shape: (98720,)
# Maximum peak amplitude: 11960

# %%
# Use entire signal for FFT
n = len(data)
freq = np.fft.rfftfreq(n, d=1/sample_rate)  # frequency bins
fft_magnitude = np.abs(np.fft.rfft(data))   # magnitude spectrum

# Plot frequency spectrum
plt.figure(figsize=(12, 4))
plt.plot(freq, fft_magnitude, color='green')
plt.title("FFT - Frequency Spectrum of SpikerBox Signal with 50 mV input")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.grid(True)
plt.xlim(0, 500)  # limit to 0–500 Hz for better visibility (adjust if needed)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# Load the .wav file
wav_path = 'C:/Users/Axioo Pongo/Documents/BYB/SpikerBox dengan input 50 mV.wav'
sample_rate, data = wavfile.read(wav_path)

# Print basic info
print(f"Sample rate: {sample_rate} Hz")
print(f"Data shape: {data.shape}")

# If stereo, take only one channel
if len(data.shape) > 1:
    data = data[:, 0]  # use left channel only

# Find max peak amplitude
peak_amplitude = np.max(np.abs(data))
print(f"Maximum peak amplitude: {peak_amplitude}")

# Create time axis in seconds
time = np.linspace(0, len(data) / sample_rate, num=len(data))

# Define how much of the signal to plot (e.g., first 0.1 seconds)
duration_to_plot = 0.1  # in seconds
samples_to_plot = int(sample_rate * duration_to_plot)

# Slice the data and time arrays
data_segment = data[:samples_to_plot]
time_segment = time[:samples_to_plot]

# Plot the zoomed-in waveform
plt.figure(figsize=(12, 4))
plt.plot(time_segment, data_segment, color='blue')
plt.title(f"SpikerBox dengan input 50 mV sine wave 70 Hz (Zoomed: {duration_to_plot*1000:.0f} ms)")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Sample rate: 5000 Hz
# Data shape: (98720,)
# Maximum peak amplitude: 11960

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# Load the .wav file
sample_rate, data = wavfile.read('C:/Users/Axioo Pongo/Documents/BYB/SpikerBox dengan input otot.wav')

# Print basic info
print(f"Sample rate: {sample_rate} Hz")
print(f"Data shape: {data.shape}")

# If stereo, take only one channel
if len(data.shape) > 1:
    data = data[:, 0]  # use left channel

# Find max peak amplitude
peak_amplitude = np.max(np.abs(data))
print(f"Maximum peak amplitude: {peak_amplitude}")

# Create time axis in seconds
time = np.linspace(0, len(data) / sample_rate, num=len(data))

# Plot the waveform
plt.figure(figsize=(12, 4))
plt.plot(time, data)
plt.title("SpikerBox dengan input otot lengan")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Sample rate: 5000 Hz
# Data shape: (155712,)
# Maximum peak amplitude: 5260

# %%
# Use entire signal for FFT
n = len(data)
freq = np.fft.rfftfreq(n, d=1/sample_rate)  # frequency bins
fft_magnitude = np.abs(np.fft.rfft(data))   # magnitude spectrum

# Plot frequency spectrum
plt.figure(figsize=(12, 4))
plt.plot(freq, fft_magnitude, color='green')
plt.title("FFT - Frequency Spectrum of SpikerBox Signal vwith muscle input")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.grid(True)
plt.xlim(0, 500)  # limit to 0–500 Hz for better visibility (adjust if needed)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# Load the .wav file
sample_rate, data = wavfile.read('C:/Users/Axioo Pongo/Documents/BYB/SpikerBox dengan input otot.wav')

# Print basic info
print(f"Sample rate: {sample_rate} Hz")
print(f"Data shape: {data.shape}")

# If stereo, take only one channel
if len(data.shape) > 1:
    data = data[:, 0]  # use left channel

# Find max peak amplitude
peak_amplitude = np.max(np.abs(data))
print(f"Maximum peak amplitude: {peak_amplitude}")

# Create time axis in seconds
time = np.linspace(0, len(data) / sample_rate, num=len(data))

# --- Set zoom range for display ---
duration_to_plot = 4.0 # in seconds (you can change to 0.5, 1.0 etc)
samples_to_plot = int(sample_rate * duration_to_plot)

# Slice the data and time arrays
data_segment = data[:samples_to_plot]
time_segment = time[:samples_to_plot]

# Plot zoomed-in waveform
plt.figure(figsize=(12, 4))
plt.plot(time_segment, data_segment, color='orange')
plt.title(f"SpikerBox dengan input otot lengan (Zoomed: {duration_to_plot*1000:.0f} ms)")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Sample rate: 5000 Hz
# Data shape: (155712,)
# Maximum peak amplitude: 5260
